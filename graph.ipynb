# %%
import random
class Node():
    def __init__(self, Val =1):
        self.edges = []
        self.val = Val
    def addEdge(self,cost,node):
        if([node,cost] not in self.edges):
            self.edges.append([node,cost])
    def removeEdge(self,cost,node):
        while([node,cost] in self.edges):
            del edges[[node,cost]]
class Graph():
    #node val is assumed to be a one dimentional possition
    def __init__(self):
        self.nodes = []
    def addNode(self,Val):
        self.nodes.append(Node(Val))
    def addUndirectedEdge(self,first,second):
        cost = abs(first.val-second.val)
        first.addEdge(cost,second)
        second.addEdge(cost,first)
    def removeUndirectedEdge(self,first,second):
        cost = abs(first.val-second.val)
        first.removeEdge(cost,second)
        second.removeEdge(cost,first)
    def adddirectedEdge(self,first,second):
        cost = abs(first.val-second.val)
        first.addEdge(cost,second)
    def removedirectedEdge(self,first,second):
        cost = abs(first.val-second.val)
        first.removeEdge(cost,second)
    def getAllNodes(self):
        return self.nodes
    def printGraph(self):
        print('This Graph has: ' + str(len(self.nodes)) + ' nodes.')
        print('The Connections are as follows:')
        for i in range(len(self.nodes)):
            print("\nnode: " + str(i) + ' has connections too:')
            for j in range(len(self.nodes[i].edges)):
                print('To node ' + str(self.nodes.index(self.nodes[i].edges[j][0])) + ' with a cost of '+ str(self.nodes[i].edges[j][1]))
            
def createRandomUnweightedGraphIter(n):
    graph = Graph()
    for i in range(n):
        graph.addNode(1)
    t = random.randint(1,n)
    temp = list(range(t))
    random.shuffle(temp)
    for i in temp:
        graph.addUndirectedEdge(graph.nodes[random.randint(0,n-1)],graph.nodes[random.randint(0,n-1)])
    return graph
print('Random grapth with five nodes\n')
temp = createRandomUnweightedGraphIter(5)
temp.printGraph()

def createLinkedList(n):
    graph = Graph()
    for i in range(n):
        graph.addNode(1)
    for i in(range(n)):
        if(i == 0):
            continue
        graph.adddirectedEdge(graph.nodes[i-1],graph.nodes[i])
    return graph
print('\nLinked list graph with 5 nodes\n')
temp = createLinkedList(5)
temp.printGraph()

class GraphSearch():
    def DFSiter(self,start,stop):
        visited = []
        search = [start]
        while (len(search) > 0):
            temp = search.pop()
            if(temp in visited):
                continue
            visited.append(temp)
            if (temp == stop):
                return visited
            for i in temp.edges:
                search.append(i[0])
        return None
        
    def DFSrec(self,start,stop):
        ret = []
        def DFSrecsearch(start,stop):
            if(start == stop):
                ret.append(start)
                return
            if(start in ret):
                return
            for i in start.edges():
                DFSrecsearch(i[0],stop)
        DFSrecsearch(start,stop)
        if(stop in ret):
            return ret
        return None
    def BFSrec(self,start,stop):
        ret = []
        queue = []
        def BFSrecsearch(self,start,stop):
            if(start == stop):
                ret.append(start)
                return
            if(start in ret):
                if(len(queue) > 0):
                    BFSrecsearch(queue.pop(0),stop)
                    return
                return
            ret.append(start)
            for i in start.edges:
                queue.append(i[0])
            BFSrecsearch(self,queue.pop(0),stop)
        BFSrecsearch(self,start,stop)
        if(len(ret)>0):
            return ret
        return None
    def BFSiter(self,start,stop):
        visited = []
        search = [start]
        while (len(search) > 0):
            temp = search.pop(0)
            if(temp in visited):
                continue
            visited.append(temp)
            if(temp == stop):
                return visited
            for i in temp.edges:
                search.append(i[0])
        return None
search = GraphSearch()
temp = createLinkedList(10000)
print('\nRecursive BFT search on linked list')
print(search.BFSrec(temp.nodes[0],temp.nodes[-1]))
temp = createLinkedList(10000)
print('\n Iterative BFT search on lined list')
print(search.BFSiter(temp.nodes[0],temp.nodes[-1]))
# Out:
# Random grapth with five nodes
#
# This Graph has: 5 nodes.
# The Connections are as follows:
#
# node: 0 has connections too:
#
# node: 1 has connections too:
# To node 3 with a cost of 0
#
# node: 2 has connections too:
#
# node: 3 has connections too:
# To node 1 with a cost of 0
#
# node: 4 has connections too:
#
# Linked list graph with 5 nodes
#
# This Graph has: 5 nodes.
# The Connections are as follows:
#
# node: 0 has connections too:
# To node 1 with a cost of 0
#
# node: 1 has connections too:
# To node 2 with a cost of 0
#
# node: 2 has connections too:
# To node 3 with a cost of 0
#
# node: 3 has connections too:
# To node 4 with a cost of 0
#
# node: 4 has connections too:
#
# Recursive BFT search on linked list
# [<__main__.Node object at 0x000001E25F880908>, <__main__.Node object at 0x000001E25F880988>, <__main__.Node object at 0x000001E25F8809C8>, <__main__.Node object at 0x000001E25F880A08>, <__main__.Node object at 0x000001E25F880A48>, <__main__.Node object at 0x000001E25F880AC8>, <__main__.Node object at 0x000001E25F880B08>, <__main__.Node object at 0x000001E25F880B48>, <__main__.Node object at 0x000001E25F880B88>, <__main__.Node object at 0x000001E25F880A88>, <__main__.Node object at 0x000001E25F880BC8>, <__main__.Node object at 0x000001E25F880C08>, <__main__.Node object at 0x000001E25F880C48>, <__main__.Node object at 0x000001E25F880C88>, <__main__.Node object at 0x000001E25F880CC8>, <__main__.Node object at 0x000001E25F880D08>, <__main__.Node object at 0x000001E25F880D48>, <__main__.Node object at 0x000001E25F880D88>, <__main__.Node object at 0x000001E25F8801C8>, <__main__.Node object at 0x000001E25F880208>, <__main__.Node object at 0x000001E25F880248>, <__main__.Node object at 0x000001E25F880288>, <__main__.Node object at 0x000001E25F8802C8>, <__main__.Node object at 0x000001E25F880308>, <__main__.Node object at 0x000001E25F880348>, <__main__.Node object at 0x000001E25F880388>, <__main__.Node object at 0x000001E25F8803C8>, <__main__.Node object at 0x000001E25F880408>, <__main__.Node object at 0x000001E25F880448>, <__main__.Node object at 0x000001E25F880488>, <__main__.Node object at 0x000001E25F8804C8>, <__main__.Node object at 0x000001E25F880508>, <__main__.Node object at 0x000001E25F880548>, <__main__.Node object at 0x000001E25F880588>, <__main__.Node object at 0x000001E25F8805C8>, <__main__.Node object at 0x000001E25F880608>, <__main__.Node object at 0x000001E25F880648>, <__main__.Node object at 0x000001E25F880688>, <__main__.Node object at 0x000001E25F8806C8>, <__main__.Node object at 0x000001E25F880708>, <__main__.Node object at 0x000001E25F880748>, <__main__.Node object at 0x000001E25F880788>, <__main__.Node object at 0x000001E25F880048>, <__main__.Node object at 0x000001E25F880088>, <__main__.Node object at 0x000001E25F8800C8>, <__main__.Node object at 0x000001E25F880108>, <__main__.Node object at 0x000001E25F880148>, <__main__.Node object at 0x000001E25F880188>, <__main__.Node object at 0x000001E25F312CC8>, <__main__.Node object at 0x000001E25F312D08>, <__main__.Node object at 0x000001E25F312D48>, <__main__.Node object at 0x000001E25F3129C8>, <__main__.Node object at 0x000001E25F312A08>, <__main__.Node object at 0x000001E25F312A48>, <__main__.Node object at 0x000001E25F312A88>, <__main__.Node object at 0x000001E25F312AC8>, <__main__.Node object at 0x000001E25F312B08>, <__main__.Node object at 0x000001E25F312B48>, <__main__.Node object at 0x000001E25F312B88>, <__main__.Node object at 0x000001E25F312BC8>, <__main__.Node object at 0x000001E25F312C08>, <__main__.Node object at 0x000001E25F312C48>, <__main__.Node object at 0x000001E25F312C88>, <__main__.Node object at 0x000001E25F3126C8>, <__main__.Node object at 0x000001E25F312708>, <__main__.Node object at 0x000001E25F312748>, <__main__.Node object at 0x000001E25F312788>, <__main__.Node object at 0x000001E25F3127C8>, <__main__.Node object at 0x000001E25F312808>, <__main__.Node object at 0x000001E25F312848>, <__main__.Node object at 0x000001E25F312888>, <__main__.Node object at 0x000001E25F3128C8>, <__main__.Node object at 0x000001E25F312948>, <__main__.Node object at 0x000001E25F3123C8>, <__main__.Node object at 0x000001E25F312448>, <__main__.Node object at 0x000001E25F3124C8>, <__main__.Node object at 0x000001E25F312548>, <__main__.Node object at 0x000001E25F3125C8>, <__main__.Node object at 0x000001E25F312648>, <__main__.Node object at 0x000001E25F3120C8>, <__main__.Node object at 0x000001E25F312148>, <__main__.Node object at 0x000001E25F3121C8>, <__main__.Node object at 0x000001E25F312248>, <__main__.Node object at 0x000001E25F3122C8>, <__main__.Node object at 0x000001E25F312348>, <__main__.Node object at 0x000001E25F312048>, <__main__.Node object at 0x000001E25EDF6388 ...
#
#  Iterative BFT search on lined list
# [<__main__.Node object at 0x000001E25F880DC8>, <__main__.Node object at 0x000001E25F880F08>, <__main__.Node object at 0x000001E25F880F48>, <__main__.Node object at 0x000001E25F880F88>, <__main__.Node object at 0x000001E25F8807C8>, <__main__.Node object at 0x000001E25F2E3E48>, <__main__.Node object at 0x000001E25F2E3E88>, <__main__.Node object at 0x000001E25F2E3EC8>, <__main__.Node object at 0x000001E25F2E3F48>, <__main__.Node object at 0x000001E25F2E3E08>, <__main__.Node object at 0x000001E25F2F4048>, <__main__.Node object at 0x000001E25F2F40C8>, <__main__.Node object at 0x000001E25F2F4148>, <__main__.Node object at 0x000001E25F2F41C8>, <__main__.Node object at 0x000001E25F2F4248>, <__main__.Node object at 0x000001E25F2F42C8>, <__main__.Node object at 0x000001E25F2F4348>, <__main__.Node object at 0x000001E25F2F43C8>, <__main__.Node object at 0x000001E25F2F4448>, <__main__.Node object at 0x000001E25F2F44C8>, <__main__.Node object at 0x000001E25F2F4548>, <__main__.Node object at 0x000001E25F2F45C8>, <__main__.Node object at 0x000001E25F2F4648>, <__main__.Node object at 0x000001E25F2